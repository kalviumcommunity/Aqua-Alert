# %% [markdown]
# # Workspace Setup Verification
# This notebook verifies that Jupyter Notebook was launched from the correct project directory and nested properly within a specific folder (`notebooks/`), rather than in the root or home directory.

# %%
import os
print("Workspace setup successful! Notebook is running from the correct directory.")
print("Current Working Directory:", os.getcwd())
# Out:
# Workspace setup successful! Notebook is running from the correct directory.
# Current Working Directory: c:\Users\prk41\Aqua-Alert\notebooks
