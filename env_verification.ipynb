# %% [markdown]
# # Environment Verification
# This notebook verifies that Jupyter can execute Python code correctly in the current environment.

# %%
import sys
print("Python Version:", sys.version)
print("Python Executable:", sys.executable)
